# %% [markdown]
# # Import libraries

# %%
# General libraries
import numpy as np

# Module
import ximinf.nn_inference as nninf
import ximinf.nn_train as nntr
import ximinf.nn_io as nnio
import ximinf.cosmo_helper as ch
import ximinf.data_helper as dh

from nn_config import nn_path
from sim_config import get_quality_mask

cosmo = ch.get_canonical("PlanckBAO18")
cosmo_cosmo = ch.to_cosmologix(cosmo)

# Jax libraries
import jax.numpy as jnp
import jax

# Plotting libraries
import matplotlib.pyplot as plt
from getdist import MCSamples, plots
# %matplotlib inline

# Warning management
from absl import logging
logging.set_verbosity(logging.ERROR)

# %% [markdown]
# # Load NN

# %%
# Parameters
models_per_group, models_config = nnio.load_autoregressive_nn(nn_path)

# %% [markdown]
# # Set device type

# %%
key = jax.random.PRNGKey(42)

# %%
device, backend, cpu, gpu = dh.setup_jax_device()
# Out:
# gpu

# %% [markdown]
# # Load data

# %%
columns = models_config['shared']['columns']
if 'z' not in columns:
    columns = columns + ['z']
    
file_path = "../data/inference_data_frame.h5"
params, data_dict = dh.load_hdf5(file_path)

# %%
inputs_infer, data_dict, mask, max_size = dh.process_simulation_results(data_dict, columns, models_config, get_quality_mask, cosmo_cosmo, disable_x64_after=True)
# Out:
# The compilation cache as grown to 2.12 GB.Caching is disabled for now.Clear the cache using `cosmologix clear-cache -j` to re-enable.Or directly from python: tools.clear_cache(jit=True)

# %%
columns = [col for col in columns if col != 'z']

# %%
columns
# Out:
# ['magobs', 'magobs_err', 'c', 'c_err', 'x1', 'x1_err', 'isup']

# %%
print(f'Sample size : {jnp.sum(mask)}')
# Out:
# Sample size : 995

# %% [markdown]
# # MCMC

# %% [markdown]
# ## Set priors

# %%
priors = models_config['shared']['priors']

# Change the priors here if needed

# if 'mabs' in priors:
#     priors['mabs']['range'] += 19.3

# %%
priors
# Out:
# {'alpha': {'range': array([-0.25, -0.07], dtype=float32), 'type': 'uniform'},
#  'beta': {'range': array([2.4, 3.6], dtype=float32), 'type': 'uniform'},
#  'gamma': {'range': array([-0.1,  0.3], dtype=float32), 'type': 'uniform'},
#  'mabs': {'range': array([-0.10000038,  0.09999847], dtype=float32),
#   'type': 'uniform'}}

# %%
for model_g in models_per_group:
    model_g.eval()  # disable dropout, etc.

global_param_names = models_config['shared']['global_param_names']
print(f"Parameters : {global_param_names}")

param_groups = models_config['shared']['param_groups']
# Out:
# Parameters : ['mabs', 'beta', 'alpha', 'gamma']

# %%
param_stats = models_config['shared']['param_stats']

normalized_priors = {}

for name, prior in priors.items():
    mu = param_stats[name]['mu']
    sigma = param_stats[name]['sigma']

    norm_range = (prior['range'] - mu) / sigma
        
    normalized_priors[name] = {
        'range': norm_range,
        'type': prior['type']  # type stays unchanged
    }


theta_init_dict = {
    name: 0.5 * (priors[name]['range'][0] + 
                 priors[name]['range'][1])
    for name in global_param_names
}

theta_init_normed_dict = {
    name: (
        theta_init_dict[name] - param_stats[name]['mu']
    ) / param_stats[name]['sigma']
    for name in global_param_names
}

theta_init_normed = jnp.array(
    [theta_init_normed_dict[name] for name in global_param_names]
)

# %% [markdown]
# ## Prepare input

# %% [markdown]
# ## Launch MCMC

# %%
# ========== MCMC Sampling ==========

# ----------------------------
# Precompute parameter indices
# ----------------------------

group_names_list = []
for g in param_groups:
    if isinstance(g, str):
        group_names_list.append([g])  # wrap single parameter in a list
    else:
        group_names_list.append(g)  
        
visible_indices, group_indices = nninf.preprocess_groups(param_groups, global_param_names)

n_points = 2000

print("Launch MCMC ...")

def log_post(theta):
    # Use the new grouped log-prob function
    return nninf.log_prob_fn_groups(
        theta,
        models_per_group,  # list of models per group
        inputs_infer,
        normalized_priors,
        visible_indices,
        group_indices,
        group_names_list
    )

# Run MCMC
key, post = nninf.sample_posterior(
    log_post,
    n_warmup=200,
    n_samples=n_points,
    init_position=theta_init_normed,
    rng_key=key
)

print("...finished")
# Out:
# Launch MCMC ...
# ...finished

# %%
n_samples, n_params = post.shape

# Convert post from array to dict with column names
post_dict = {name: post[:, i] for i, name in enumerate(global_param_names)}

# Unnormalize each parameter
post_unnormed_dict = nntr.unnormalize(post_dict, param_stats)

# Convert back to array for plotting
post_unnormed = jnp.stack([post_unnormed_dict[name] for name in global_param_names], axis=1)

ranges_from_priors = [
    (float(priors[name]['range'][0]), float(priors[name]['range'][1]))
    for name in global_param_names
]

# %%
samples = np.array(post_unnormed)

gdsamples = MCSamples(
    samples=samples,
    names=global_param_names,
    labels=global_param_names,
)

g = plots.get_subplot_plotter()

g.triangle_plot(
    gdsamples,
    filled=True,
    contour_colors=["#1F487E"],
    param_limits={
        name: r for name, r in zip(global_param_names, ranges_from_priors)
    }
)

g.export("./corner.png")
plt.show()
# Out:
# Removed no burn in

# %%
np.save("../data/results/sbi_posterior_dict.npy", {
    "offset": post_unnormed[:, global_param_names.index("mabs")],
    # "alpha_low": post_unnormed[:, global_param_names.index("alpha_low")],
    # "alpha_high": post_unnormed[:, global_param_names.index("alpha_high")],
    "alpha": post_unnormed[:, global_param_names.index("alpha")],
    # "x1_ref": post_unnormed[:, global_param_names.index("x1_ref")],
    "beta": post_unnormed[:, global_param_names.index("beta")],
    "step": post_unnormed[:, global_param_names.index("gamma")],
    # "sigma_int": post_unnormed[:, global_param_names.index("sigma_int")]
    })

# %% [markdown]
# # OTHER

# %%
n_cols = len(columns)
n_rows = int(jnp.ceil(n_params / n_cols))

fig, axes = plt.subplots(
    n_rows,
    n_cols,
    figsize=(4 * n_cols, 3 * n_rows),
    squeeze=False
)

axes = axes.flatten()

for i in range(n_params):

    axes[i].plot(post_unnormed[:, i])

    axes[i].set_title(global_param_names[i])

    axes[i].set_xlabel("Sample")

    axes[i].set_ylabel("Value")

# Remove unused subplots
for i in range(n_params, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
def autocorr_fft(x, max_lag):
    """
    FFT-based autocorrelation estimator (biased, energy-normalized).
    Returns lags [0, max_lag-1].
    """

    n = x.shape[0]

    # Remove mean (important for statistical correctness)
    x = x - jnp.mean(x)

    # Zero-padding to avoid circular convolution effects
    nfft = 2 * n

    # FFT
    X = jnp.fft.rfft(x, n=nfft)

    # Power spectrum
    S = X * jnp.conj(X)

    # Inverse FFT -> autocorrelation
    acf_full = jnp.fft.irfft(S, n=nfft)

    # Normalize by zero-lag value
    acf_full = acf_full / acf_full[0]

    # Keep only non-negative lags
    return acf_full[:max_lag]

# %%
autocorr_fft(post_unnormed[:, global_param_names.index("alpha")], 100)
# Out:
# Array([ 1.00000000e+00, -1.27131164e-01,  3.35485078e-02,  1.50374658e-02,
#         2.31125392e-02,  9.00107343e-03, -1.16149765e-02, -5.64028835e-03,
#        -4.20800410e-02,  1.22321378e-02, -4.32993006e-03, -1.72957312e-02,
#         1.11138623e-03, -2.98670563e-03,  1.68946702e-02, -2.44986322e-02,
#        -3.41469906e-02, -3.22919129e-03, -9.94722452e-03, -1.42847048e-03,
#        -2.87158992e-02, -1.66708641e-02,  9.74737015e-03,  2.78923032e-03,
#        -1.19642951e-02,  2.93201599e-02, -4.51479573e-03, -2.51635928e-02,
#        -6.77588861e-04,  3.66420113e-02,  1.19107724e-04,  4.17170697e-04,
#         4.01294492e-02,  1.59813445e-02,  1.53597118e-03,  3.00556831e-02,
#        -2.50814725e-02, -2.96107400e-02,  2.53290590e-02,  9.15160496e-03,
#        -1.74502581e-02, -7.86167569e-03,  2.55777892e-02, -1.54912686e-02,
#         3.41503620e-02, -4.25073430e-02, -1.94237579e-03,  2.44984925e-02,
#         6.91597490e-03,  1.32040484e-02,  2.45137210e-03, -2.00582333e-02,
#        -1.70820989e-02,  2.60968180e-03, -2.26238947e-02,  1.69553291e-02,
#        -4.10424247e-02, -2.91448291e-02,  6.66831899e-03,  4.80778702e-03,
#        -6.27401471e-02,  5.50042838e-02, -6.24294207e-03, -2.14734897e-02,
#         1.62200239e-02,  1.13121765e-02, -1.32641755e-03,  3.88839059e-02,
#         4.21633720e-02, -9.56071261e-03, -3.32733318e-02,  3.42098810e-02,
#        -8.59408546e-03,  4.03160639e-02, -2.35548783e-02, -1.24326199e-02,
#        -1.99328531e-02, -1.63265299e-02, -8.40826612e-03,  2.67895381e-03,
#        -1.51262740e-02, -2.12457925e-02,  1.48332836e-02,  3.08800191e-02,
#        -8.57840292e-03, -5.75790852e-02, -1.15303509e-02, -2.34842468e-02,
#        -2.43146420e-02,  2.51567038e-03,  1.66326258e-02, -8.38625710e-03,
#        -3.32841836e-02,  4.56373878e-02,  4.75357473e-03, -1.88559934e-03,
#         3.57701145e-02,  2.99633611e-02,  9.91800148e-03, -3.25021707e-02],      dtype=float32)
